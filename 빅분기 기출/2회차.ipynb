# %% [markdown]
# <a href="https://colab.research.google.com/github/mini1115/TIL/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0%20%EA%B8%B0%EC%B6%9C/2%ED%9A%8C%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2b1ff2e1-e87e-49bf-8dc6-d9e6d4cfd462" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b1ff2e1-e87e-49bf-8dc6-d9e6d4cfd462">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("members.csv")
df.head()
# Out:
#      id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0  id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2021-07-16  6820.0
# 1  id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2021-05-12  2534.0
# 2  id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2021-03-16  7312.0
# 3  id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2021-07-21   493.0
# 4  id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2021-03-07  1338.0

# %% [markdown]
# # 문제1
# - 데이터셋(basic1.csv)의 'views' 컬럼을 기준으로 상위 10개의 데이터를 구하고,
#
# - 'views'컬럼 10개 중 최소값으로 데이터를 대체한 후,
# - ' age'컬럼에서 80 이상인 데이터의'views 컬럼 평균값 구하기

# %%
df.sort_values('views',ascending=False,inplace=True)
min = df['views'][:10].min()
df.iloc[:10,-1] = min
ans = df.loc[df['age']>=80]['views'].mean()
round(ans,2)
# Out:
# 5674.04

# %% [markdown]
# # 문제2
# - 데이터셋(basic1.csv)의 앞에서 순서대로 70% 데이터만 활용해서,
# - 'f1'컬럼 결측치를 중앙값으로 채우기 전후의 표준편차를 구하고
# - 두 표준편차 차이 계산하기

# %%
df = pd.read_csv('basic1.csv')

new_l = (int)(len(df)*0.7)
df = df.iloc[:new_l]
len(df)

before = df['f1'].std()

m = df['f1'].median()
df['f1']= df['f1'].fillna(m)

after = df['f1'].std()

diff = after - before
print("표준편차의 차 :",diff)
# Out:
# 표준편차의 차 : -3.2965018033960725

# %% [markdown]
# # 문제3
# - 데이터셋(basic1.csv)의 'age'컬럼의 이상치를 더하시오!
# - 단, 평균으로부터 '표준편차*1.5'를 벗어나는 영역을 이상치라고 판단함

# %%
df  = pd.read_csv('basic1.csv')
df.head(3)
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986

# %%
df.describe()
# Out:
#               age          f1          f2          f5
# count  100.000000   69.000000  100.000000  100.000000
# mean    50.963000   66.043478    0.650000   56.734537
# std     30.442759   19.453893    0.715979   28.454244
# min    -13.500000   12.000000    0.000000    9.796378
# 25%     26.875000   51.000000    0.000000   29.269869
# 50%     52.500000   63.000000    1.000000   64.113099
# 75%     77.000000   78.000000    1.000000   81.025055
# max    100.000000  111.000000    2.000000   98.429899

# %%
m = df['age'].mean()
st = df['age'].std() * 1.5
# 최솟값 평균 - 표준편차 1.5  / 최댓값 평균 + 표준편차 *1.5
min_range = m - st
max_range = m + st
print(min_range ," && " ,max_range)
# Out:
# 5.298862216116952  &&  96.62713778388306

# %% [markdown]
# # **작업형2**
#
# ### 전자상거래 배송 데이터
#
# #### 제품 배송 시간에 맞춰 배송되었는지 예측모델 만들기
#
#     학습용 데이터 (X_train, y_train)을 이용하여 배송 예측 모형을 만든 후,
#     이를 평가용 데이터(X_test)에 적용하여 얻은 예측 확률값을
#     다음과 같은 형식의 CSV파일로 생성하시오
#     (제출한 모델의 성능은 ROC-AUC 평가지표에 따라 채점)
#
#     예 : 수험번호.csv파일
#
# #### 예제 결과
# ```
# ID, Reached.on.Time_Y.N
# 4733,0.6
# 2040,0.8
# 5114,0.45
# 2361,0.23
# 5996,0.43
# ```

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e6958c77-9a44-4d54-9875-23e9a0577d64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6958c77-9a44-4d54-9875-23e9a0577d64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

train = pd.read_csv("X_train.csv")
target = pd.read_csv("y_train.csv")
test = pd.read_csv("X_test.csv")
# x_train.shape, y_train.shape,test.shape
# train.head()
# test.head()
# x_train.info()
# x_train.describe()
# x_train.isnull().sum()

#분류 target
train = train.drop('ID',axis=1)
test_ID = test.pop('ID')
combined = pd.concat([train,test])
combined_oh = pd.get_dummies(combined)
train = combined_oh[:len(train)]
test = combined_oh[len(train):]
# score: 0.7776
# from sklearn.preprocessing import LabelEncoder
# cols = train.select_dtypes(include='O').columns
# for col in cols:
#   le = LabelEncoder()
#   train[col] = le.fit_transform(train[col])
#   test[col] = le.transform(test[col])
# # score: 0.7714

# 스케일링
from sklearn.preprocessing import MinMaxScaler
cols = train.select_dtypes(exclude='O').columns
scaler = MinMaxScaler()
train[cols] = scaler.fit_transform(train[cols])
test[cols] = scaler.fit_transform(test[cols])
# 0.7776190476190475

from sklearn.model_selection import train_test_split
X_tr,X_val,y_tr,y_val = train_test_split(train,target['Reached.on.Time_Y.N'],test_size=0.2,random_state=0)
# X_tr.shape,X_val.shape,y_tr.shape,y_val.shape

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth= 5, n_estimators=200,random_state=0)
rf.fit(X_tr,y_tr)
pred = rf.predict_proba(X_val)
# import lightgbm as lgb
# lg = lgb.LGBMClassifier(random_state=0,verbose=-1)
# lg.fit(X_tr,y_tr)
# pred = lg.predict_proba(X_val)

from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_val,pred[:,1])
print('score:',score)

pred = rf.predict_proba(test)
submit = pd.DataFrame({'ID':test_ID,'Reached.on.Time_Y.N':pred[:,1]})
submit.to_csv('1234.csv',index=False)
pd.read_csv('1234.csv').head(5)
# Out:
# <ipython-input-42-f243aebaec41>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[cols] = scaler.fit_transform(train[cols])
# <ipython-input-42-f243aebaec41>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[cols] = scaler.fit_transform(test[cols])
# score: 0.7776190476190475
#       ID  Reached.on.Time_Y.N
# 0   8285             0.450639
# 1  10192             0.479039
# 2   8675             0.456080
# 3   5753             0.462280
# 4    448             0.760290
